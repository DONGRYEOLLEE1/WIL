# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # (주)제주마미 Scrapping

# %%
url = 'https://smartstore.naver.com/jejumami/category/1b0788867510451f936db79964a103da?cp=1'
source = requests.get(url)
soup = BeautifulSoup(source.content, 'html.parser')
table = soup.find('li', {'class':'-qHwcFXhj0'})
div = table.find('strong', {'class':'QNNliuiAk3'})
price = table.find('span', {'class':'nIAdxeTzhx'})
detail = table.find('p', {'class':'vChbm1yu9U'}).text
print(div.text)
print(price.text)
print(detail)
# Out:
# [한라산아래첫마을] 제주메밀 메밀가루600g
# 12,000
# 한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸 자연의 선물 제주메밀 타타리메밀은 콜레스테롤을 낮추는 루틴 성분이 풍부하게 함유하고 있고 암 예방과 치료에 좋은 셀런을 비롯한 단백질, 아미노산, 필수지방산, 칼륨, 마그네슘 등이 함유되어 있습니다. 루틴은 혈당과 혈청 콜레스테롤 저하 효과가 뛰어나 혈압을 내리게 하고 혈관벽을 튼튼하게 하여 다이어트와 당뇨, 혈압이 높으신분에 효능이 있다고 알려졌습니다. 이러한 루틴이 일반 메밀에 비해 100배나 많은 타타리메밀~~ 이렇게 다양한 영양소가 있어 미국

# %% [markdown]
# ## (주)제주마미 상품이름

# %%
url = 'https://smartstore.naver.com/jejumami/category/1b0788867510451f936db79964a103da?cp=1'
source = requests.get(url)
soup = BeautifulSoup(source.content, 'html.parser')
li = soup.find('li', {'class':'-qHwcFXhj0'})
li
# Out:
# <li class="-qHwcFXhj0"><a class="_3BkKgDHq3l N=a:lst.product linkAnchor" href="/jejumami/products/4961883042"><div class="MClmEyr46E"><span class="_29UGw2moU8"><span class="text blind">BEST</span></span></div><div class="_2Yq8Q_jTJv"><div class="_3VHN1dJCno"><div class="_2JNWBGd-04 _3uKZ70Wwcp EnqpMc_sIs _3nJcVYiGGz"><img alt="[한라산아래첫마을] 제주메밀 메밀가루600g" class="_25CKxIKjAk" src="https://shop-phinf.pstatic.net/20200607_5/1591497901550asmqu_JPEG/28858639916611751_62843720.jpg?type=f295_381"/></div></div></div><strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀가루600g</strong><div class="_23DThs7PLJ"><strong><span class="nIAdxeTzhx">12,000</span>원</strong></div><p class="vChbm1yu9U">한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸 자연의 선물 제주메밀 타타리메밀은 콜레스테롤을 낮추는 루틴 성분이 풍부하게 함유하고 있고 암 예방과 치료에 좋은 셀런을 비롯한 단백질, 아미노산, 필수지방산, 칼륨, 마그네슘 등이 함유되어 있습니다. 루틴은 혈당과 혈청 콜레스테롤 저하 효과가 뛰어나 혈압을 내리게 하고 혈관벽을 튼튼하게 하여 다이어트와 당뇨, 혈압이 높으신분에 효능이 있다고 알려졌습니다. 이러한 루틴이 일반 메밀에 비해 100배나 많은 타타리메밀~~ 이렇게 다양한 영양소가 있어 미국</p></a><div class
# ...

# %%
soup1 = BeautifulSoup(source.text, 'html.parser')


dd = soup.find_all('strong', class_='QNNliuiAk3')
dd
# Out:
# [<strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀가루600g</strong>,
#  <strong class="QNNliuiAk3">자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)</strong>,
#  <strong class="QNNliuiAk3">제주흑보리, 현미 뻥튀기 호끌락칩스20g 8개</strong>,
#  <strong class="QNNliuiAk3">우도 땅콩 기름으로 튀겨 고소한 제주 담은 김부각(4개)</strong>,
#  <strong class="QNNliuiAk3">착한 아기간식, 제주흑보리,현미과자 호끌락칩스 60g 4개</strong>,
#  <strong class="QNNliuiAk3">김녕해녀 만제 제주톳장</strong>,
#  <strong class="QNNliuiAk3">제주 담은 김부각7개 선물세트</strong>,
#  <strong class="QNNliuiAk3">국내산 현미와 제주의 청보리 제주의 산듸쌀 누룽지의 혼합 누룽지 제주밥씸누룽지</strong>,
#  <strong class="QNNliuiAk3">건강간식 감귤쌀칩, 호끌락칩스 감귤쌀칩(4개)</strong>,
#  <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀쌀(600g)</strong>,
#  <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀차 제주타타리100%(티백차, 알곡차)</strong>,
#  <strong class="QNNliuiAk3">현미와 하수오 제주밥씸 하수오 누룽지</strong>,
#  <strong class="QNNliuiAk3">어른간식, 보리과자 호끌락칩스 60g  1Box(20개입)</strong>,
#  <strong class="QNNliuiAk3">사무실 간식, 건강과자 호끌락칩스 20g 1Box</strong>]

# %%
for found in soup.find_all('li'):
    print(found.text)
# Out:
# 제주를 그대로
# 재료를 그대로
# 정성을 그대로
# 전체상품
# 묻고 답하기
# 공지사항
# 리뷰이벤트
# 쇼핑스토리
# 판매자 정보
# 홈
# (총 14개)전체상품카테고리 더보기
# 인기도순
# 누적판매순
# 낮은가격순
# 최신등록순
# 리뷰많은순
# 평점높은순
# 리스트뷰
# 이미지뷰
# 큰이미지뷰
# 갤러리뷰
# BEST[한라산아래첫마을] 제주메밀 메밀가루600g12,000원한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸 자연의 선물 제주메밀 타타리메밀은 콜레스테롤을 낮추는 루틴 성분이 풍부하게 함유하고 있고 암 예방과 치료에 좋은 셀런을 비롯한 단백질, 아미노산, 필수지방산, 칼륨, 마그네슘 등이 함유되어 있습니다. 루틴은 혈당과 혈청 콜레스테롤 저하 효과가 뛰어나 혈압을 내리게 하고 혈관벽을 튼튼하게 하여 다이어트와 당뇨, 혈압이 높으신분에 효능이 있다고 알려졌습니다. 이러한 루틴이 일반 메밀에 비해 100배나 많은 타타리메밀~~ 이렇게 다양한 영양소가 있어 미국리뷰20평점4.9/5찜하기찜하기상품 간략보기
# BEST자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)4,500원비온뒤 고사리 청정한 제주 한라산 중산간에서 자란 자연산 고사리를 준비했습니다. 고사리나물 한 번 드시려고 물에 하루 불리는 번거로움 없이 바로바로 요리해 산에서 나는 소고기를 즐기세요 4월 제주에 고사리 장마로 쑥 자란 햇고사리는 단백질, 칼슘, 철분, 무기질이 풍부해 혈압과 콜레스테롤 조절에 효과가 좋고 변비도 예방해 봄을 대표하는 산나물입니다. 특히 제주도 고사리는 다른 지역 고사리보다 통통하고 부드러운 식감으로 고사리 중 으뜸입니다. 이제 더 이상 고사리를 물에 불리고 삶는 번거로움 없이 간편하게 요리해 즐기세요! 신선하고 리뷰125평점4.8/5찜하기찜하기상품 간략보기
# ...

# %%
ul = soup.find('ul', {'class':'wOWfwtMC_3 FR2H3hWxUo _7iBijuoyJl'})
for found in ul.find_all('li'):
    print(found.text)
# Out:
# BEST[한라산아래첫마을] 제주메밀 메밀가루600g12,000원한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸 자연의 선물 제주메밀 타타리메밀은 콜레스테롤을 낮추는 루틴 성분이 풍부하게 함유하고 있고 암 예방과 치료에 좋은 셀런을 비롯한 단백질, 아미노산, 필수지방산, 칼륨, 마그네슘 등이 함유되어 있습니다. 루틴은 혈당과 혈청 콜레스테롤 저하 효과가 뛰어나 혈압을 내리게 하고 혈관벽을 튼튼하게 하여 다이어트와 당뇨, 혈압이 높으신분에 효능이 있다고 알려졌습니다. 이러한 루틴이 일반 메밀에 비해 100배나 많은 타타리메밀~~ 이렇게 다양한 영양소가 있어 미국리뷰20평점4.9/5찜하기찜하기상품 간략보기
# BEST자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)4,500원비온뒤 고사리 청정한 제주 한라산 중산간에서 자란 자연산 고사리를 준비했습니다. 고사리나물 한 번 드시려고 물에 하루 불리는 번거로움 없이 바로바로 요리해 산에서 나는 소고기를 즐기세요 4월 제주에 고사리 장마로 쑥 자란 햇고사리는 단백질, 칼슘, 철분, 무기질이 풍부해 혈압과 콜레스테롤 조절에 효과가 좋고 변비도 예방해 봄을 대표하는 산나물입니다. 특히 제주도 고사리는 다른 지역 고사리보다 통통하고 부드러운 식감으로 고사리 중 으뜸입니다. 이제 더 이상 고사리를 물에 불리고 삶는 번거로움 없이 간편하게 요리해 즐기세요! 신선하고 리뷰125평점4.8/5찜하기찜하기상품 간략보기
# BEST제주흑보리, 현미 뻥튀기 호끌락칩스20g 8개10,000원할인 전 가격12,000원16%할인갓 도정한 국내산 현미와 청정 제주 흑보리 재료를 합성 첨가물 없이 튀기지 않고 구워서 만들었습니다. 호끌락칩스의 호끌락은 작고 귀엽다는 뜻의 제주 사투리입니다. 한입에 쏙 먹을 수 있도록 작은 말모양과 하루방모양으로 제주를 담았습니다. 좋은 재료와 엄마의 마음으로 정성을 다한 영양 간식입니다.리뷰54평점4.8/5찜하기찜하기상품 간략보기
# ...

# %%
name = ul.find('strong', {'class':'QNNliuiAk3'})
print(name)
# Out:
# <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀가루600g</strong>

# %%
name2 = ul.find('strong', {'class':'QNNliuiAk3'})
print(name2)
# Out:
# <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀가루600g</strong>

# %%
product_name = soup.select('strong.QNNliuiAk3')
product_name
# Out:
# [<strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀가루600g</strong>,
#  <strong class="QNNliuiAk3">자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)</strong>,
#  <strong class="QNNliuiAk3">제주흑보리, 현미 뻥튀기 호끌락칩스20g 8개</strong>,
#  <strong class="QNNliuiAk3">우도 땅콩 기름으로 튀겨 고소한 제주 담은 김부각(4개)</strong>,
#  <strong class="QNNliuiAk3">착한 아기간식, 제주흑보리,현미과자 호끌락칩스 60g 4개</strong>,
#  <strong class="QNNliuiAk3">김녕해녀 만제 제주톳장</strong>,
#  <strong class="QNNliuiAk3">제주 담은 김부각7개 선물세트</strong>,
#  <strong class="QNNliuiAk3">국내산 현미와 제주의 청보리 제주의 산듸쌀 누룽지의 혼합 누룽지 제주밥씸누룽지</strong>,
#  <strong class="QNNliuiAk3">건강간식 감귤쌀칩, 호끌락칩스 감귤쌀칩(4개)</strong>,
#  <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀 메밀쌀(600g)</strong>,
#  <strong class="QNNliuiAk3">[한라산아래첫마을] 제주메밀차 제주타타리100%(티백차, 알곡차)</strong>,
#  <strong class="QNNliuiAk3">현미와 하수오 제주밥씸 하수오 누룽지</strong>,
#  <strong class="QNNliuiAk3">어른간식, 보리과자 호끌락칩스 60g  1Box(20개입)</strong>,
#  <strong class="QNNliuiAk3">사무실 간식, 건강과자 호끌락칩스 20g 1Box</strong>]

# %%
product_name[1].text
# Out:
# '자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)'

# %%
details = soup.select('p.vChbm1yu9U')
details
# Out:
# [<p class="vChbm1yu9U">한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸 자연의 선물 제주메밀 타타리메밀은 콜레스테롤을 낮추는 루틴 성분이 풍부하게 함유하고 있고 암 예방과 치료에 좋은 셀런을 비롯한 단백질, 아미노산, 필수지방산, 칼륨, 마그네슘 등이 함유되어 있습니다. 루틴은 혈당과 혈청 콜레스테롤 저하 효과가 뛰어나 혈압을 내리게 하고 혈관벽을 튼튼하게 하여 다이어트와 당뇨, 혈압이 높으신분에 효능이 있다고 알려졌습니다. 이러한 루틴이 일반 메밀에 비해 100배나 많은 타타리메밀~~ 이렇게 다양한 영양소가 있어 미국</p>,
#  <p class="vChbm1yu9U">비온뒤 고사리 청정한 제주 한라산 중산간에서 자란 자연산 고사리를 준비했습니다. 고사리나물 한 번 드시려고 물에 하루 불리는 번거로움 없이 바로바로 요리해 산에서 나는 소고기를 즐기세요 4월 제주에 고사리 장마로 쑥 자란 햇고사리는 단백질, 칼슘, 철분, 무기질이 풍부해 혈압과 콜레스테롤 조절에 효과가 좋고 변비도 예방해 봄을 대표하는 산나물입니다. 특히 제주도 고사리는 다른 지역 고사리보다 통통하고 부드러운 식감으로 고사리 중 으뜸입니다. 이제 더 이상 고사리를 물에 불리고 삶는 번거로움 없이 간편하게 요리해 즐기세요! 신선하고 </p>,
#  <p class="vChbm1yu9U">갓 도정한 국내산 현미와 청정 제주 흑보리 재료를 합성 첨가물 없이 튀기지 않고 구워서 만들었습니다. 호끌락칩스의 호끌락은 작고 귀엽다는 뜻의 제주 사투리입니다. 한입에 쏙 먹을 수 있도록 작은 말모양과 하루방모양으로 제주를 담았습니다. 좋은 재료와 엄마의 마음으로 정성을 다한 영양 간식입니다.</p>,
#  <p class="vChbm1yu9U">우도땅콩기름과 청정 제주의 햇살과 바람으로 만든 제주 담은 김부각 MSG NO 보존료 NO 첨가물 NO 상품 상세 정보</p>,
# ...

# %%
price = soup.select('span.nIAdxeTzhx')
price
# Out:
# [<span class="nIAdxeTzhx">12,000</span>,
#  <span class="nIAdxeTzhx">4,500</span>,
#  <span class="nIAdxeTzhx">10,000</span>,
#  <span class="nIAdxeTzhx">12,000</span>,
#  <span class="nIAdxeTzhx">10,000</span>,
#  <span class="nIAdxeTzhx">12,000</span>,
#  <span class="nIAdxeTzhx">10,000</span>,
#  <span class="nIAdxeTzhx">12,000</span>,
#  <span class="nIAdxeTzhx">4,300</span>,
#  <span class="nIAdxeTzhx">6,000</span>,
#  <span class="nIAdxeTzhx">19,900</span>,
#  <span class="nIAdxeTzhx">10,000</span>,
#  <span class="nIAdxeTzhx">12,000</span>,
#  <span class="nIAdxeTzhx">11,000</span>,
#  <span class="nIAdxeTzhx">8,000</span>,
#  <span class="nIAdxeTzhx">10,000</span>,
#  <span class="nIAdxeTzhx">60,000</span>,
#  <span class="nIAdxeTzhx">72,000</span>]

# %%
import urllib.parse
import urllib.request

url = 'https://smartstore.naver.com/jejumami/products/4961883042'
source = requests.get(url)
soup = BeautifulSoup(source.text, 'html.parser')
print(soup)
#r = soup.find('div', {'id':'REVIEW'})
#print(r)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요" name="description"/>
# <meta content="생생메밀맛국수,냠냠맛있는,몸에좋은영양소,구수한맛,글루텐프리,제주메밀,메밀전병,메밀가루,메밀국수,한라산메밀,기타분말가루,한라산아래첫마을영농조합법인,제주메밀,제주메밀 메밀가루,제주마미" name="keywords"/>
# <meta content="제주메밀 메밀가루 : 제주마미" property="og:title"/>
# <meta content="https://shop-phinf.pstatic.net/20200607_5/1591497901550asmqu_JPEG/28858639916611751_62843720.jpg?type=o640" property="og:image"/>
# <meta content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="제주메밀 메밀가루 : 제주마미" name="twitter:title"/>
# ...

# %%
with urllib.request.urlopen(url) as response:
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요" name="description"/>
# <meta content="생생메밀맛국수,냠냠맛있는,몸에좋은영양소,구수한맛,글루텐프리,제주메밀,메밀전병,메밀가루,메밀국수,한라산메밀,기타분말가루,한라산아래첫마을영농조합법인,제주메밀,제주메밀 메밀가루,제주마미" name="keywords"/>
# <meta content="제주메밀 메밀가루 : 제주마미" property="og:title"/>
# <meta content="https://shop-phinf.pstatic.net/20200607_5/1591497901550asmqu_JPEG/28858639916611751_62843720.jpg?type=o640" property="og:image"/>
# <meta content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="제주메밀 메밀가루 : 제주마미" name="twitter:title"/>
# ...

# %%
df_title = []
df_price = []
df_detail = []

for i in range(0, 14):
    pd_title = product_name[i].text
    pd_price = price[i].text
    pd_detail = details[i].text
    
    df_title.append(pd_title)
    df_price.append(pd_price)
    df_detail.append(pd_detail)
    
product = pd.DataFrame({'상품명':df_title, '가격':df_price, '상세':df_detail})
product
# Out:
#                                             상품명      가격  \
# 0                      [한라산아래첫마을] 제주메밀 메밀가루600g  12,000
# 1              자연산 생고사리 청정한 한라산 비온뒤 고사리(180g3개)   4,500
# 2                     제주흑보리, 현미 뻥튀기 호끌락칩스20g 8개  10,000
# 3               우도 땅콩 기름으로 튀겨 고소한 제주 담은 김부각(4개)  12,000
# 4              착한 아기간식, 제주흑보리,현미과자 호끌락칩스 60g 4개  10,000
# 5                                  김녕해녀 만제 제주톳장  12,000
# 6                              제주 담은 김부각7개 선물세트  10,000
# 7   국내산 현미와 제주의 청보리 제주의 산듸쌀 누룽지의 혼합 누룽지 제주밥씸누룽지  12,000
# 8                     건강간식 감귤쌀칩, 호끌락칩스 감귤쌀칩(4개)   4,300
# 9                     [한라산아래첫마을] 제주메밀 메밀쌀(600g)   6,000
# 10         [한라산아래첫마을] 제주메밀차 제주타타리100%(티백차, 알곡차)  19,900
# 11                         현미와 하수오 제주밥씸 하수오 누룽지  10,000
# 12             어른간식, 보리과자 호끌락칩스 60g  1Box(20개입)  12,000
# 13                  사무실 간식, 건강과자 호끌락칩스 20g 1Box  11,000
#
#                                                    상세
# 0   한라산 아래 첫 마을이 드리는 제주의 프리미엄 슈퍼푸드 신비한 화산섬 제주가 키워낸...
# ...

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url ='https://smartstore.naver.com/jejumami/products/4961883042'
html = requests.get(url, headers = headers).text
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate" >
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta name="description" content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요">
# <meta name="keywords" content="생생메밀맛국수,냠냠맛있는,몸에좋은영양소,구수한맛,글루텐프리,제주메밀,메밀전병,메밀가루,메밀국수,한라산메밀,기타분말가루,한라산아래첫마을영농조합법인,제주메밀,제주메밀 메밀가루,제주마미">
# <meta property="og:title" content="제주메밀 메밀가루 : 제주마미">
# <meta property="og:image" content="https://shop-phinf.pstatic.net/20200607_5/1591497901550asmqu_JPEG/28858639916611751_62843720.jpg?type=o640">
# <meta property="og:description" content="한라산아래 첫 마을이 드리는 건강한 선물 제주메밀 메밀가루로 글루텐 없는 건강한 식생활을 즐기세요">
# <meta property="og:type" content="article">
# <meta name="twitter:title" content="제주메밀 메밀가루 : 제주마미">
# ...
