# %%
import os

from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## 커스텀 이미지

# %%
# !python detect.py --source images/cafe.jpg
# Out:
# detect: weights=yolov5s.pt, source=images/cafe.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-165-gec4b6dd torch 1.9.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 C:\Users\User\yolov5\images\cafe.jpg: 480x640 14 persons, 1 bench, 10 chairs, 2 dining tables, 1 tv, Done. (0.009s)
# Speed: 1.0ms pre-process, 9.0ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp8

# %% [markdown]
# ### 결과

# %%
file_path = 'C:/Users/User/yolov5/runs/detect/exp8/cafe.jpg'

plt.figure(figsize = (20, 20))
image = Image.open(file_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 커스텀 영상
# - [Source](https://youtu.be/jNQXAC9IVRw)

# %% [markdown]
# ### Youtube URL 직접가져와서 연결

# %%
import pafy

# %%
# !python detect.py --source https://youtu.be/jNQXAC9IVRw
# Out:
# WARNING: Environment does not support cv2.imshow() or PIL Image.show() image displays
# cv2.imshow() is disabled in Docker environments
# detect: weights=yolov5s.pt, source=https://youtu.be/jNQXAC9IVRw, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-165-gec4b6dd torch 1.9.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# 1/1: https://youtu.be/jNQXAC9IVRw...  Success (284 frames 320x240 at 15.00 FPS)
#
# 0: 480x640 1 person, 1 elephant, 1 backpack, Done. (0.739s)
# 0: 480x640 1 person, 1 elephant, Done. (0.005s)
# 0: 480x640 1 person, 1 elephant, Done. (0.004s)
# ...

# %%
file_path = 'D:/downloads/test_result1.jpg'

plt.figure(figsize = (20, 20))
image = Image.open(file_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 영상 다운로드 후, 연결

# %%
# !python detect.py --source D:/downloads/test.mp4
# Out:
# detect: weights=yolov5s.pt, source=D:/downloads/test.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-165-gec4b6dd torch 1.9.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/9415) D:\downloads\test.mp4: 384x640 8 cars, 3 traffic lights, Done. (0.013s)
# video 1/1 (2/9415) D:\downloads\test.mp4: 384x640 6 cars, 3 traffic lights, Done. (0.009s)
# video 1/1 (3/9415) D:\downloads\test.mp4: 384x640 5 cars, 3 traffic lights, Done. (0.009s)
# video 1/1 (4/9415) D:\downloads\test.mp4: 384x640 5 cars, 2 traffic lights, Done. (0.010s)
# ...

# %% [markdown]
# #### 결과확인

# %%
file_path = 'D:/downloads/test_result.jpg'

plt.figure(figsize = (20, 20))
image = Image.open(file_path)
plt.imshow(image)
plt.axis('off')
plt.show()
